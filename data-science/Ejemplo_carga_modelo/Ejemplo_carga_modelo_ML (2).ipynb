# %%
# !pip install -r requirements.txt -q

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, OrdinalEncoder
from xgboost import XGBClassifier
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import FunctionTransformer
import shap
import joblib

# %%
import custom_class_copy as cc
import feature_engineering_functions as func

# %%
model = joblib.load('modelo_XGB.joblib')

# %%
custom_model = cc.CustomPrediction(model)

# %%
data = {
    "aerolinea": "9E",
    "aeropuerto_origen": "JFK",
    "aeropuerto_destino": "MSP",
    "fecha_vuelo": "2026-12-12 12:12"
    }

# %%
entrada = pd.DataFrame(data, index=[0])
entrada["fecha_vuelo"] = pd.to_datetime(entrada["fecha_vuelo"])
entrada.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, 0 to 0
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   aerolinea           1 non-null      object
#  1   aeropuerto_origen   1 non-null      object
#  2   aeropuerto_destino  1 non-null      object
#  3   fecha_vuelo         1 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), object(3)
# memory usage: 40.0+ bytes

# %%
r = custom_model.predict(entrada)

# %%
dict(r[0])
# Out:
# {'Predicción': 'A tiempo',
#  'Probabilidad': np.float64(0.5299999713897705),
#  'Distancia': np.float64(1029.0)}

# %%
custom_model.explain(entrada)
# Out:
#                     Importancia
# aerolinea              0.350850
# hora de vuelo          0.224164
# aeropuerto_origen      0.112364
# mes de vuelo           0.095875
# día de la semana       0.094220
# aeropuerto_destino     0.059140
# fin_de_semana          0.011297
# distancia_millas       0.009908
