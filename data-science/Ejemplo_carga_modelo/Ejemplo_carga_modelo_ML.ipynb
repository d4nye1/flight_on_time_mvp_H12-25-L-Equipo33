# %%
# !pip install -r requirements.txt -q
# Out:
# Requirement already satisfied: geopandas==1.1.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: imbalanced-learn==0.14.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (0.14.0)
# Requirement already satisfied: joblib==1.5.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (1.5.3)
# Requirement already satisfied: numpy==2.0.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (2.0.2)
# Requirement already satisfied: pandas==2.2.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (2.2.2)
# Requirement already satisfied: pandas-datareader==0.10.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (0.10.0)
# Requirement already satisfied: pandas-gbq==0.30.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (0.30.0)
# Requirement already satisfied: pandas-stubs==2.2.2.240909 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (2.2.2.240909)
# Requirement already satisfied: scikit-learn==1.6.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (1.6.1)
# Requirement already satisfied: shap==0.50.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 10)) (0.50.0)
# Requirement already satisfied: shapely==2.1.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 11)) (2.1.2)
# Requirement already satisfied: sklearn-pandas==2.2.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 12)) (2.2.0)
# Requirement already satisfied: xgboost==3.1.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 13)) (3.1.2)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas==1.1.1->-r requirements.txt (line 1)) (0.12.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from geopandas==1.1.1->-r requirements.txt (line 1)) (25.0)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from geopandas==1.1.1->-r requirements.txt (line 1)) (3.7.2)
# Requirement already satisfied: scipy<2,>=1.11.4 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn==0.14.0->-r requirements.txt (line 2)) (1.16.3)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn==0.14.0->-r requirements.txt (line 2)) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas==2.2.2->-r requirements.txt (line 5)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas==2.2.2->-r requirements.txt (line 5)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas==2.2.2->-r requirements.txt (line 5)) (2025.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from pandas-datareader==0.10.0->-r requirements.txt (line 6)) (6.0.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from pandas-datareader==0.10.0->-r requirements.txt (line 6)) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from pandas-gbq==0.30.0->-r requirements.txt (line 7)) (75.2.0)
# Requirement already satisfied: db-dtypes<2.0.0,>=1.0.4 in /usr/local/lib/python3.12/dist-packages (from pandas-gbq==0.30.0->-r requirements.txt (line 7)) (1.4.4)
# Requirement already satisfied: pyarrow>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from pandas-gbq==0.30.0->-r requirements.txt (line 7)) (18.1.0)
# Requirement already satisfied: pydata-google-auth>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from pandas-gbq==0.30.0->-r requirements.txt (line 7)) (1.9.1)
# Requirement already satisfied: google-api-core<3.0.0,>=2.10.2 in /usr/local/lib/python3.12/dist-packages (from pandas-gbq==0.30.0->-r requirements.txt (line 7)) (2.28.1)
# Requirement already satisfied: google-auth>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from pandas-gbq==0.30.0->-r requirements.txt (line 7)) (2.43.0)
# Requirement already satisfied: google-auth-oauthlib>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from pandas-gbq==0.30.0->-r requirements.txt (line 7)) (1.2.2)
# Requirement already satisfied: google-cloud-bigquery<4.0.0,>=3.4.2 in /usr/local/lib/python3.12/dist-packages (from pandas-gbq==0.30.0->-r requirements.txt (line 7)) (3.38.0)
# Requirement already satisfied: types-pytz>=2022.1.1 in /usr/local/lib/python3.12/dist-packages (from pandas-stubs==2.2.2.240909->-r requirements.txt (line 8)) (2025.2.0.20251108)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.12/dist-packages (from shap==0.50.0->-r requirements.txt (line 10)) (4.67.1)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.12/dist-packages (from shap==0.50.0->-r requirements.txt (line 10)) (0.0.8)
# Requirement already satisfied: numba>=0.54 in /usr/local/lib/python3.12/dist-packages (from shap==0.50.0->-r requirements.txt (line 10)) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from shap==0.50.0->-r requirements.txt (line 10)) (3.1.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from shap==0.50.0->-r requirements.txt (line 10)) (4.15.0)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.12/dist-packages (from xgboost==3.1.2->-r requirements.txt (line 13)) (2.28.9)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0,>=2.10.2->pandas-gbq==0.30.0->-r requirements.txt (line 7)) (1.72.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0,>=2.10.2->pandas-gbq==0.30.0->-r requirements.txt (line 7)) (5.29.5)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0,>=2.10.2->pandas-gbq==0.30.0->-r requirements.txt (line 7)) (1.26.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.13.0->pandas-gbq==0.30.0->-r requirements.txt (line 7)) (6.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.13.0->pandas-gbq==0.30.0->-r requirements.txt (line 7)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.13.0->pandas-gbq==0.30.0->-r requirements.txt (line 7)) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from google-auth-oauthlib>=0.7.0->pandas-gbq==0.30.0->-r requirements.txt (line 7)) (2.0.0)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in /usr/local/lib/python3.12/dist-packages (from google-cloud-bigquery<4.0.0,>=3.4.2->pandas-gbq==0.30.0->-r requirements.txt (line 7)) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-bigquery<4.0.0,>=3.4.2->pandas-gbq==0.30.0->-r requirements.txt (line 7)) (2.8.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.54->shap==0.50.0->-r requirements.txt (line 10)) (0.43.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from pyogrio>=0.7.2->geopandas==1.1.1->-r requirements.txt (line 1)) (2025.11.12)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas==2.2.2->-r requirements.txt (line 5)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pandas-datareader==0.10.0->-r requirements.txt (line 6)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pandas-datareader==0.10.0->-r requirements.txt (line 6)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pandas-datareader==0.10.0->-r requirements.txt (line 6)) (2.5.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery<4.0.0,>=3.4.2->pandas-gbq==0.30.0->-r requirements.txt (line 7)) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery<4.0.0,>=3.4.2->pandas-gbq==0.30.0->-r requirements.txt (line 7)) (1.71.2)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from google-resumable-media<3.0.0,>=2.0.0->google-cloud-bigquery<4.0.0,>=3.4.2->pandas-gbq==0.30.0->-r requirements.txt (line 7)) (1.7.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.13.0->pandas-gbq==0.30.0->-r requirements.txt (line 7)) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.7.0->pandas-gbq==0.30.0->-r requirements.txt (line 7)) (3.3.1)

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, OrdinalEncoder
from xgboost import XGBClassifier
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import FunctionTransformer
import shap
import joblib

# %%
import custom_class as cc
import feature_engineering_functions as func

# %%
model = joblib.load('modelo_XGB.joblib')

# %%
custom_model = cc.CustomPrediction(model)

# %%
data = {
    "aerolinea": "MQ",
    "aeropuerto_origen": "JFK",
    "aeropuerto_destino": "DFW",
    "fecha_vuelo": "2024-01-24 15:19"
    }

# %%
entrada = pd.DataFrame(data, index=[0])
entrada["fecha_vuelo"] = pd.to_datetime(entrada["fecha_vuelo"])
entrada.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, 0 to 0
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   aerolinea           1 non-null      object
#  1   aeropuerto_origen   1 non-null      object
#  2   aeropuerto_destino  1 non-null      object
#  3   fecha_vuelo         1 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), object(3)
# memory usage: 40.0+ bytes

# %%
custom_model.predict(entrada)
# Out:
# [{'Predicción': 'Retrasado', 'Probabilidad': '53.2599983215332 %'}]

# %%
custom_model.explain(entrada)
# Out:
#                                  Importancia
# categorical__aerolinea              0.214074
# día de la semana                    0.142419
# hora de vuelo                       0.116976
# categorical__aeropuerto_destino     0.109578
# mes de vuelo                        0.087374
# categorical__aeropuerto_origen      0.070242
# numerical__distancia_millas         0.039882
# bool__fin_de_semana                 0.000880
